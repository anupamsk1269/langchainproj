# %%
# Tell Python to look one directory up for your custom modules if needed
import sys
sys.path.append("..")

import config
from langchain_openai import ChatOpenAI

# Initialize the model using your centralized configuration
llm = ChatOpenAI(
    model=config.DEFAULT_MODEL, 
    api_key=config.OPENAI_API_KEY, 
    temperature=0
)

response = llm.invoke("Are we connected?")
print(response.content)
# Out:
# Yes, we are connected! I'm here to assist you with any questions or topics you'd like to discuss. How can I help you today?

# %%
import os
from pathlib import Path
from dotenv import load_dotenv

# 1. Dynamically locate the absolute path to the project root
ROOT_DIR = Path(__file__).resolve().parent
ENV_PATH = ROOT_DIR / ".env"

# 2. Load the environment file
load_dotenv(dotenv_path=ENV_PATH)

# 3. Centralize configurations as clean variables
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
DEFAULT_MODEL = "gpt-4o-mini"

# Quick sanity check to protect you from empty keys
if not OPENAI_API_KEY:
    raise ValueError(f"CRITICAL: OPENAI_API_KEY is missing from {ENV_PATH}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       2 from pathlib import Path
#       3 from dotenv import load_dotenv
#       4
#       5 # 1. Dynamically locate the absolute path to the project root
# ----> 6 ROOT_DIR = Path(__file__).resolve().parent
#       7 ENV_PATH = ROOT_DIR / ".env"
#       8
#       9 # 2. Load the environment file
#
# NameError: name '__file__' is not defined

# %%
import os
from pathlib import Path
from dotenv import load_dotenv

# Use os.getcwd() instead of __file__ when inside a Jupyter Notebook
ROOT_DIR = Path(os.getcwd()).resolve()
# If your notebook is inside the notebooks/ folder, we go up one level to find the root
if ROOT_DIR.name == "notebooks":
    ROOT_DIR = ROOT_DIR.parent

ENV_PATH = ROOT_DIR / ".env"

# 2. Load the environment file
load_dotenv(dotenv_path=ENV_PATH)

# 3. Centralize configurations as clean variables
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
DEFAULT_MODEL = "gpt-4o-mini"

if not OPENAI_API_KEY:
    raise ValueError(f"CRITICAL: OPENAI_API_KEY is missing from {ENV_PATH}")
    
print("Success! Config loaded correctly.")
# Out:
# Success! Config loaded correctly.

# %%
import sys
import os

# 1. Tell Python to look in the parent directory (the root folder)
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), os.pardir)))

# 2. Now you can cleanly import your config file
import config

# 3. Verify it worked by printing your default model
print("Config imported successfully!")
print(f"Default Model set to: {config.DEFAULT_MODEL}")
# Out:
# Config imported successfully!
# Default Model set to: gpt-4o-mini

# %%
from langchain_openai import OpenAI
import config
openai_llm = OpenAI()
gemini_pro = GoogleGenerativeAI(model="gemini-2.5-flash")
response = openai_llm.invoke("Tell me a joke about light bulb!")
print("OpenAI Response " + response)
response = gemini_pro.invoke("Tell me a joke about light bulb!")
print("Gemini Response " + response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 from langchain_openai import OpenAI
#       2 import config
#       3 openai_llm = OpenAI()
# ----> 4 gemini_pro = GoogleGenerativeAI(model="gemini-2.5-flash")
#       5 response = openai_llm.invoke("Tell me a joke about light bulb!")
#       6 print("OpenAI Response " + response)
#       7 response = gemini_pro.invoke("Tell me a joke about light bulb!")
#
# NameError: name 'GoogleGenerativeAI' is not defined

# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), os.pardir)))
import config

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage, SystemMessage

# Overwrite the model string here directly with the updated stable model name
gemini_model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash", 
    google_api_key=config.GEMINI_API_KEY,
    temperature=0.3
)

messages = [
    SystemMessage(content="You are a brilliant software architect who explains things via cooking analogies."),
    HumanMessage(content="What is a vector embedding?")
]

response = gemini_model.invoke(messages)

print(response.content)
# Out:
# Alright, pull up a chair, grab a spoon, and let's talk about the secret sauce of modern AI: **vector embeddings**.
#
# Imagine you're not just a software architect, but a Michelin-star chef, running the most advanced kitchen in the world. You don't just *know* your ingredients; you understand their very *essence*.
#
# ### The Analogy: Your Ingredient "Flavor Profile Card"
#
# **What is a vector embedding?**
# A vector embedding is like creating a highly detailed, multi-dimensional **"Flavor Profile Card"** for every single ingredient in your pantry, your fridge, and even the wild herbs you forage.
#
# 1.  **The Ingredient (The "Thing" to Embed):**
#     *   Let's say you have a **tomato**. In the digital world, this could be a word ("tomato"), an image of a tomato, a recipe containing tomatoes, or even a customer who likes tomatoes.
#
# 2.  **The Flavor Profile Card (The "Vector"):**
# ...

# %%
from langchain_openai import OpenAI
from langchain_google_genai import GoogleGenerativeAI
import config
openai_llm = OpenAI()
gemini_pro = GoogleGenerativeAI(model="gemini-2.5-flash")
response = openai_llm.invoke("Tell me a joke about light bulb!")
print("OpenAI Response " + response)
response = gemini_pro.invoke("Tell me a joke about light bulb!")
print("Gemini Response " + response)
# Out:
# OpenAI Response
#
# Why did the light bulb go to school?
#
# To get brighter!
# Gemini Response Why did the light bulb get good grades?
#
# Because it was so **bright**!

# %%
import sys
import os

# 1. Routing for config setup
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), os.pardir)))
import config

# 2. Import the correct, modern Chat Model wrappers
from langchain_openai import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI

# 3. Initialize the Chat interfaces using your config
openai_chat = ChatOpenAI(
    model=config.DEFAULT_MODEL, # gpt-4o-mini
    api_key=config.OPENAI_API_KEY
)

gemini_chat = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash", 
    google_api_key=config.GEMINI_API_KEY
)

# 4. Invoke them the exact same way
prompt = "Tell me a joke about light bulb!"

openai_response = openai_chat.invoke(prompt)
gemini_response = gemini_chat.invoke(prompt)

# 5. Note: Modern chat models return an AIMessage object, 
# so we grab the text content using '.content'
print("OpenAI Response: " + openai_response.content)
print("\nGemini Response: " + gemini_response.content)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 14
#      10 from langchain_google_genai import ChatGoogleGenerativeAI
#      11
#      12 # 3. Initialize the Chat interfaces using your config
#      13 openai_chat = ChatOpenAI(
# ---> 14     model=config.DEFAULT_MODEL, # gpt-4o-mini
#      15     api_key=config.OPENAI_API_KEY
#      16 )
#      17
#
# AttributeError: module 'config' has no attribute 'DEFAULT_MODEL'

# %%
import os
from pathlib import Path
from dotenv import load_dotenv

# 1. Dynamically locate the absolute path to the project root
ROOT_DIR = Path(__file__).resolve().parent if "__file__" in locals() else Path(os.getcwd()).resolve()
if ROOT_DIR.name == "notebooks":
    ROOT_DIR = ROOT_DIR.parent

ENV_PATH = ROOT_DIR / ".env"

# 2. Load the sensitive keys from .env into environment variables
load_dotenv(dotenv_path=ENV_PATH)

# 3. Pull sensitive keys from environment memory
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

# 4. Define non-sensitive default configurations right here in code
DEFAULT_MODEL = "gpt-4o-mini"
DEFAULT_GEMINI_MODEL = "gemini-2.5-flash"

# Quick safeguard checks
if not OPENAI_API_KEY:
    raise ValueError(f"CRITICAL: OPENAI_API_KEY is missing from {ENV_PATH}")
if not GEMINI_API_KEY:
    raise ValueError(f"CRITICAL: GEMINI_API_KEY is missing from {ENV_PATH}")

# %%
import sys
import os

# 1. Routing for config setup
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), os.pardir)))
import config

# 2. Import the correct, modern Chat Model wrappers
from langchain_openai import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_anthropic import ChatAnthropic

# 3. Initialize the Chat interfaces using your config
openai_chat = ChatOpenAI(
    model=config.DEFAULT_MODEL, # gpt-4o-mini
    api_key=config.OPENAI_API_KEY
)

gemini_chat = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash", 
    google_api_key=config.GEMINI_API_KEY
)
anthropic_chat = ChatAnthropic(
    model=config.DEFAULT_ANTHROPIC_MODEL,
    api_key=config.ANTHROPIC_API_KEY
)

# 4. Invoke them the exact same way
prompt = "Tell me a joke about light bulb!"

openai_response = openai_chat.invoke(prompt)
gemini_response = gemini_chat.invoke(prompt)
anthropic_response = anthropic_chat.invoke(prompt)

# 5. Note: Modern chat models return an AIMessage object, 
# so we grab the text content using '.content'
print("OpenAI Response: " + openai_response.content)
print("\nGemini Response: " + gemini_response.content)
print("\nAnthropic Response: " + anthropic_response.content)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[3], line 33
#      29 prompt = "Tell me a joke about light bulb!"
#      30
#      31 openai_response = openai_chat.invoke(prompt)
#      32 gemini_response = gemini_chat.invoke(prompt)
# ---> 33 anthropic_response = anthropic_chat.invoke(prompt)
#      34
#      35 # 5. Note: Modern chat models return an AIMessage object,
#      36 # so we grab the text content using '.content'
#
# File /opt/miniconda3/envs/langchain_ai/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
# ...

# %%
# !pip install -qU langchain-anthropic

# %%
import sys
import os

# 1. Routing for config setup
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), os.pardir)))
import config

# 2. Import the correct, modern Chat Model wrappers
from langchain_openai import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_anthropic import ChatAnthropic

# 3. Initialize the Chat interfaces using your config
openai_chat = ChatOpenAI(
    model=config.DEFAULT_MODEL, # gpt-4o-mini
    api_key=config.OPENAI_API_KEY
)

gemini_chat = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash", 
    google_api_key=config.GEMINI_API_KEY
)
anthropic_chat = ChatAnthropic(
    model="claude-sonnet-4-6",
    api_key=config.ANTHROPIC_API_KEY
)

# 4. Invoke them the exact same way
prompt = "Write a Python function to calculate factorial"
messages

openai_response = openai_chat.invoke(prompt)
gemini_response = gemini_chat.invoke(prompt)
anthropic_response = anthropic_chat.invoke(prompt)

# 5. Note: Modern chat models return an AIMessage object, 
# so we grab the text content using '.content'
print("OpenAI Response: " + openai_response.content)
print("\nGemini Response: " + gemini_response.content)
print("\nAnthropic Response: " + anthropic_response.content)
# Out:
# OpenAI Response: How many programmers does it take to change a light bulb?
#
# None! That's a hardware problem!
#
# Gemini Response: Why did the light bulb get such good grades?
#
# Because it had so many **bright ideas**!
#
# Anthropic Response: Here's a classic one:
#
# **How many programmers does it take to change a light bulb?**
#
# *None — that's a hardware problem!* 😄
#
# ---
#
# Or a simple one:
#
# **How many politicians does it take to change a light bulb?**
#
# *Two — one to change it and one to change it back again!* 💡
#
# Hope that lit up your day! 😄
