# %%
import os
from dotenv import load_dotenv
import torch
import langchain

load_dotenv()

print("LangChain version:", langchain.__version__)
print("Apple Silicon GPU (MPS) Available:", torch.backends.mps.is_available())
# Out:
# LangChain version: 1.3.10
# Apple Silicon GPU (MPS) Available: True

# %%
import torch
from diffusers import StableDiffusionPipeline

# Check device: will use 'mps' on Apple Silicon, fallback to 'cpu'
device = "mps" if torch.backends.mps.is_available() else "cpu"
print(f"Using device: {device}")

model_id = "runwayml/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float32)
pipe = pipe.to(device)

prompt = "A cinematic photograph of an ancient stone temple hidden in a lush rainforest and Anupam Sarkar's facebook profile picture next to it"
image = pipe(prompt).images[0]
image.show()
# Out:
# Using device: mps
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
prompt = "A cinematic photograph of an ancient stone temple hidden in a lush rainforest"
image = pipe(prompt).images[0]

# Just write the variable name as the final line:
image
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
